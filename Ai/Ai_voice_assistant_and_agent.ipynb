# %% [markdown]
# <a href="https://colab.research.google.com/github/raajmalhotra143/Google-colab/blob/main/Ai/Ai_voice_assistant_and_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ai voice assistant and agent
# 1st install Install the Library:-

# %%
pip install google-genai

# %%
import os
import subprocess
from google import genai
from google.genai import types

# --- 1. Define Real Tools ---
def read_file(file_path: str):
    """Reads a file from the user's project."""
    try:
        if not os.path.exists(file_path): return "File not found."
        with open(file_path, 'r') as f: return f.read()
    except Exception as e: return str(e)

def run_terminal(command: str):
    """Executes a terminal command (Sandboxed)."""
    # Safety: Block dangerous commands for this demo
    if "rm" in command or "sudo" in command: return "Command blocked for safety."

    try:
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        return result.stdout + result.stderr
    except Exception as e: return str(e)

# --- 2. Initialize Client with Tools ---
client = genai.Client(api_key="AIzaSyD5V9whqanBh_83TF8alaapCxSW-USLgvM")

# Create a chat session with tools enabled
chat = client.chats.create(
    model="gemini-2.0-flash",
    config=types.GenerateContentConfig(
        tools=[read_file, run_terminal], # Pass actual functions here!
        automatic_function_calling=types.AutomaticFunctionCallingConfig(
            disable=False # This tells Gemini to execute the Python functions for you
        ),
        system_instruction="You are an autonomous coding agent. You can read files and run commands to help the user."
    )
)

def run_agent(user_prompt):
    # The SDK handles the loop:
    # 1. Model decides to call tool -> 2. SDK runs function -> 3. SDK sends result back -> 4. Model replies
    response = chat.send_message(user_prompt)
    return response.text

# %%
run_voice_agent()
# Out:
# Agent says: Hello, I am your voice assistant. How can I help you?
# Error playing audio: [Errno -9996] Invalid output device (no default output device)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-2821162661.py in <cell line: 0>()
# ----> 1 run_voice_agent()
#
# /tmp/ipython-input-4255598619.py in run_voice_agent()
#       2     speak_text("Hello, I am your voice assistant. How can I help you?")
#       3     while True:
# ----> 4         user_input_text = recognize_speech()
#       5         if user_input_text.lower() == "exit":
#       6             speak_text("Goodbye!")
#
# /tmp/ipython-input-1642273970.py in recognize_speech()
#       8     """Converts speech from the microphone to text."""
#       9     r = sr.Recognizer()
# ---> 10     with sr.Microphone() as source:
#      11         print("Say something!")
# ...

# %%
# !apt-get update
# !apt-get install -y portaudio19-dev

# %%
pip install PyAudio

# %%
pip install PyAudio

# %%
run_voice_agent()

# %%
def run_voice_agent():
    print("Agent says: Hello, I am your text-based assistant. How can I help you?")
    while True:
        user_input_text = input("You say: ")
        if user_input_text.lower() == "exit":
            print("Agent says: Goodbye!")
            break
        if user_input_text:
            response_text = run_agent(user_input_text)
            print(f"Agent says: {response_text}")

# %% [markdown]
# You can now run `run_voice_agent()` to start the voice assistant. Remember that you might need to grant microphone access if prompted by your browser or operating system.

# %%
import speech_recognition as sr
from gtts import gTTS
from pydub import AudioSegment
from pydub.playback import play
import io

def recognize_speech():
    """Converts speech from the microphone to text."""
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)

    try:
        text = r.recognize_google(audio)
        print(f"You said: {text}")
        return text
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        return ""
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return ""

def speak_text(text):
    """Converts text to speech and plays it."""
    print(f"Agent says: {text}")
    try:
        tts = gTTS(text=text, lang='en')
        fp = io.BytesIO()
        tts.write_to_fp(fp)
        fp.seek(0)
        audio = AudioSegment.from_file(fp, format="mp3")
        play(audio)
    except Exception as e:
        print(f"Error playing audio: {e}")

# Example usage (uncomment to test):
# speak_text("Hello, how can I help you today?")
# user_input = recognize_speech()
# if user_input:
#     speak_text(f"You just said: {user_input}")

# %% [markdown]
# Now, we can create a `run_voice_agent` function that integrates these voice capabilities with our existing `run_agent`.

# %% [markdown]
# To add voice capabilities, we'll need to install a couple of libraries: `SpeechRecognition` for converting speech to text and `gTTS` for converting text to speech.

# %%
pip install SpeechRecognition gTTS pydub

# %%
run_voice_agent()
# Out:
# Agent says: Hello, I am your text-based assistant. How can I help you?
# Agent says: I do not have the information you are looking for. I can help you with reading files and running terminal commands. Is there anything I can help you with?
# Agent says: I am a large language model, built by Google.
#
# Agent says: I am a text-based agent. I can't directly be a voice agent.
#
# Agent says: To make me a voice agent, you would need to connect me to a text-to-speech (TTS) and speech-to-text (STT) system. Here's a general outline of the steps involved:
#
# 1.  **Choose a TTS Engine:** Select a TTS engine that suits your needs. Some popular options include Google Cloud Text-to-Speech, Amazon Polly, Microsoft Azure Text to Speech, or open-source options like eSpeak.
#
# 2.  **Choose a STT Engine:** Select a STT engine. Some popular options include Google Cloud Speech-to-Text, Amazon Transcribe, Microsoft Azure Speech to Text, or open-source options like CMU Sphinx.
#
# ...

# %% [markdown]
# Next, we'll define new functions that use these libraries to handle voice input and output. We'll also need `pydub` to play the generated audio.

# %%
response_text = run_agent("List the files in the current directory.")
print(response_text)
